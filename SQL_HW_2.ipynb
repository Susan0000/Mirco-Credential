# %% [markdown]
# <a href="https://colab.research.google.com/github/Susan0000/Mirco-Credential/blob/main/SQL_HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name : Susan Lin

# %% [markdown]
# Lesson 5: Joins and Unions

# %% [markdown]
# # 1. Join the film to the film_actor table.
#
# SELECT film.file_id, file.title, film.description, film.release_year, file.language_id, film.rental_duration, film.rental_rate, film.length, film.replacement_cost, film.rating, film.last_update, film.special_features, film.fulltext, actor_id
#
# FROM film
#
# FULL JOIN film_actor
#
# ON film.film_id = film_actor.film_id

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Join the actor table to the film_actor table.
#
# SELECT actor.actor_id, actor.first_name, actor.last_name, actor.last_update, film_actor.film_id
#
# FROM actor
#
# FULL JOIN film_actor
#
# ON actor.actor_id = film_actor.actor_id;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Try to join the actor, film_actor, and film table together (3 joins!)
#
# SELECT film.file_id, file.title, film.description, film.release_year, file.language_id, film.rental_duration, film.rental_rate, film.length, film.replacement_cost, film.rating, film.last_update, film.special_features, film.fulltext, film_actor.actor_id, actor.first_name, actor.last_name
#
# FROM film AS film
#
# FULL JOIN
#
# film_actor AS film_actor
#
# ON film.film_id = film_actor.film_id
#
# FULL JOIN
#
# actor AS actor
#
# ON film_actor.last_update = actor.last_update;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
