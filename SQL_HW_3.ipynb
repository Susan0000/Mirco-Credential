# %% [markdown]
# <a href="https://colab.research.google.com/github/Susan0000/Mirco-Credential/blob/main/SQL_HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Susan Lin

# %% [markdown]
# # 1. Create a table with the following parameters:
#
# DROP TABLE IF EXISTS customers;
#
# CREATE TABLE customers(
#
# Customer ID serial,
#
# CustomerName varchar(255),
#
# Address varchar(255),
#
# City varchar(255),
#
# PostalCode varchar(255),
#
# Country varchar(255),
#
# Email varchar(255)
#
# );

# %% [markdown]
# # 2. Insert 3 rows of data into these columns using INSERT. The data you insert should make sense for the column.
#
# INSERT INTO customers (customername, address, city, postalcode, country, email)
#
# VALUES
#
# ('Alejandra', 'Ocean Ave', 'Brooklyn', '11249', 'USA', 'ald@gmail.com'),
#
# ('Roger', '3rd Kingsway', 'Brooklyn', '11223', 'USA', 'ROG@hotmail.com'),
#
# ('Caroll', 'forth place', 'Queens', '1235', 'USA', 'carll@gmail.com');
#
#
# SELECT * FROM customers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Use an UPDATE to modify any portion of the data
#
# UPDATE customers
#
# SET email='alejandra@hotmail.com'
#
# WHERE customername LIKE 'Alejandra%';
#
#
# SELECT * FROM customers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Finally, write a statement to delete one row of data.
#
# DELETE FROM customers where customerid = 2;
#
# SELECT * FROM customers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Part 2 Using the following Link
#
# https://github.com/niteen11/cuny_lagcc_micro_credential_data_analytics/tree/main/Track%20A/Unit%205%20-%20SQL_%20Relational%20Databases/guided%20exercise
#
# First you have to create a table than upload the data ,safe the table in to your Laptop and change the
# path accordingly.usr the following link for creating table,

# %%
DROP TABLE IF EXISTS student;
CREATE TABLE student
(
    id serial PRIMARY KEY,
    first_name character varying,
    last_name character varying,
    email character varying,
    gender character varying,
    work_phone character varying,
    book_preference_hardcopy boolean 
);

# %%
DROP TABLE IF EXISTS student_marks;
CREATE TABLE student_marks
(
    id serial PRIMARY KEY,
    student_reg_id integer,
    student_id integer,
	unit2 integer,
	unit3 integer,
	unit4 integer,
	unit5 integer    
);

# %% [markdown]
# # -- students with the highest marks in Unit 4
#
# SELECT student.first_name, student.last_name, student.id, student_marks.id, student_marks.unit4
#
# FROM student INNER JOIN student_marks
#
# ON student.id = student_marks.id ORDER BY unit4 DESC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- Find students scored between 89 and 100 unit4
#
# SELECT student.first_name, student.last_name, student.id, student_marks.id, student_marks.unit4
#
# FROM student INNER JOIN student_marks
#
# ON student.id_marks.id WHERE unit4 BETWEEN 89 and 100 ORDER BY unit4 ASC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- List out the email
#
# SELECT first_name, last_name, email FROM student;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- List out the male
#
# SELECT first_name, last_name, gender FROM student
#
# WHERE gender ='Male';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- List out the female
#
# SELECT first_name, last_name, gender FROM student
#
# WHERE gender= 'Female';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- Grade avg from all the units
#
# SELECT AVG(unit2+unit3+unit4+unit5)/4 AS Average
#
# FROM student_marks;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- Unit 5 grade avg
#
# SELECT AVG(unit5) AS unit5_avg from student_marks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- Individual avg of students
#
# SELECT student_id, avg(unit2+unit3+unit4+uni5)/4 AS Average FROM student_marks
#
# GROUP BY student_id;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- List students who have phone number that start with 401
#
# SELECT first_name, last_name, work_phone FROM student WHERE work_phone LIKE '401%';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- List students who have phone number that start with 401
#
# SELECT last_name, work_phone FROM student WHERE work_phone LIKE '347%';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # List of students in order
#
# SELECT first_name, last_name FROM student
#
# ORDER BY 2, 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # -- List of students who like hard copy books
#
# SELECT count(book_preference_hardcopy) FROM student WHERE book_preference_hardcopy is TRUE

# %% [markdown]
# ![image.png](data:image/png;base64,...)
